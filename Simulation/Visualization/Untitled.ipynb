# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py as h5

# %%
# Load data
with h5.File("C:/Users/hyli93/Downloads/inclined_part_9_y_field_ds.h5", 'r') as h5file:
    data = np.array(h5file['field'])

# %%
plt.figure(figsize=(12, 10))
plt.imshow(np.log(np.sum(data, axis=2)), cmap='jet', vmin=8)
plt.colorbar()
plt.show()
