# %%
import numpy as np
import h5py as h5
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
# Variable Delay Branch
k_variable_holders = []

with h5.File("C:/Users/haoyuan/Desktop/Research/Projects/Split Delay Design/instability_inclined.h5", 'r') as source:
    name_list = list(source.keys())
    for k in list(source.keys()):
        print(k)
        k_variable_holders.append(np.array(source[k]))
        #print(source[k].shape)

# ===============================================================================================================
k_fixed_holders = []

with h5.File("C:/Users/haoyuan/Desktop/Research/Projects/Split Delay Design/instability_fixed.h5", 'r') as source:
    for k in list(source.keys()):
        #print(k)
        k_fixed_holders.append(np.array(source[k]))
        #print(source[k].shape)
# Out:
# crystal 0 x axis
# crystal 0 y axis
# crystal 0 z axis
# crystal 1 x axis
# crystal 1 y axis
# crystal 1 z axis
# crystal 2 x axis
# crystal 2 y axis
# crystal 2 z axis
# crystal 3 x axis
# crystal 3 y axis
# crystal 3 z axis
# grating 1 x axis
# grating 1 y axis
# grating 1 z axis
# grating 2 x axis
# grating 2 y axis
# grating 2 z axis

# %% [markdown]
# # Get the unperturbed wave vector

# %%
k0_fix = k_fixed_holders[0][100]
print(k0_fix)

k0_var = k_variable_holders[0][100]
print(k0_var)
# Out:
# [ 0.00000000e+00 -1.29034561e-11  5.06773076e+04]
# [1.21700144e-06 3.64625105e-06 5.06773076e+04]

# %% [markdown]
# # Calculate the momentum difference

# %%
k_fix = np.stack(k_fixed_holders)
k_fix_diff = k_fix - k0_fix[np.newaxis, np.newaxis, :]

k_var = np.stack(k_variable_holders)
k_var_diff = k_var - k0_var[np.newaxis, np.newaxis, :]

# %% [markdown]
# # plot the differences

# %%
plt.figure(figsize=(15, 7))

for x in range(18):
    plt.plot(np.arange(-100, 101) / 10., k_fix_diff[x, :, 0], label=name_list[x])

plt.xlim([-11, 15])

plt.ylabel("Delta k in um^-1")
plt.xlabel("Misalignment in urad")
plt.title("Delta kx")

plt.legend()
plt.show()

# %%
plt.figure(figsize=(15, 7))

for x in range(18):
    plt.plot(np.arange(-100, 101) / 10., k_fix_diff[x, :, 1], label=name_list[x])

plt.xlim([-11, 15])

plt.ylabel("Delta k in um^-1")
plt.xlabel("Misalignment in urad")
plt.title("Delta ky")

plt.legend()
plt.show()

# %%
plt.figure(figsize=(15, 7))

for x in range(18):
    plt.plot(np.arange(-100, 101) / 10., k_fix_diff[x, :, 2], label=name_list[x])

plt.xlim([-11, 15])

plt.ylabel("Delta k in um^-1")
plt.xlabel("Misalignment in urad")
plt.title("Delta kz")

plt.legend()
plt.show()

# %% [markdown]
# # Fit the Deviation Matrix

# %%
gradient_fix_holder = np.zeros((3, 18))

angles = np.arange(-100, 101) / 10.  # urad

for x in range(18):
    for y in range(3):
        
        # Linear fit slope
        slope, intercept, r_value, p_value, std_err = linregress(angles, k_fix_diff[x, :, y])

        # Slope through the origin
        slope_o = np.dot(angles, k_fix_diff[x, :, y]) / np.dot(angles, angles)
        
        #print(slope - slope_o)
        
        gradient_fix_holder[y, x] = slope_o

# %%
gradient_var_holder = np.zeros((3, 18))

angles = np.arange(-100, 101) / 10.  # urad

for x in range(18):
    for y in range(3):
        
        # Linear fit slope
        slope, intercept, r_value, p_value, std_err = linregress(angles, k_var_diff[x, :, y])

        # Slope through the origin
        slope_o = np.dot(angles, k_var_diff[x, :, y]) / np.dot(angles, angles)
        
        #print(slope - slope_o)
        
        gradient_var_holder[y, x] = slope_o

# %%
print(np.max(gradient_fix_holder), np.max(gradient_var_holder))

np.set_printoptions(precision=3)
print(gradient_fix_holder.T)
# Out:
# 0.10135461517384559 0.1013546832003189
# [[ 0.000e+00  1.014e-01  3.041e-05]
#  [ 0.000e+00 -1.432e-30 -1.241e-29]
#  [-3.272e-02 -1.001e-24 -2.503e-24]
#  [ 0.000e+00 -1.014e-01 -3.041e-05]
#  [ 0.000e+00 -1.432e-30 -1.241e-29]
#  [-3.272e-02  3.004e-24  3.630e-24]
#  [ 0.000e+00  1.014e-01  3.041e-05]
#  [ 0.000e+00 -1.432e-30 -1.241e-29]
#  [-3.272e-02 -2.003e-24  2.378e-24]
#  [ 0.000e+00 -1.014e-01 -3.041e-05]
#  [ 0.000e+00  0.000e+00  0.000e+00]
#  [-3.272e-02  1.001e-24  2.503e-24]
#  [ 0.000e+00  8.763e-14 -1.520e-05]
#  [ 0.000e+00  0.000e+00  0.000e+00]
#  [ 1.520e-05  9.779e-28 -1.146e-29]
#  [ 0.000e+00 -3.667e-28  1.520e-05]
#  [ 0.000e+00  3.031e-33  0.000e+00]
#  [-1.520e-05 -3.667e-28  0.000e+00]]

# %%
print(gradient_var_holder.T)
# Out:
# [[ 6.766e-02  1.014e-01 -3.041e-05]
#  [ 4.775e-31  0.000e+00 -1.241e-29]
#  [-3.272e-02  9.504e-07 -2.835e-10]
#  [-5.074e-02 -1.014e-01  3.041e-05]
#  [ 0.000e+00  0.000e+00 -1.241e-29]
#  [-3.272e-02  9.504e-07 -2.839e-10]
#  [ 1.691e-02  1.014e-01 -3.041e-05]
#  [ 4.775e-31  0.000e+00 -1.241e-29]
#  [-3.272e-02  1.962e-12  6.215e-13]
#  [ 0.000e+00 -1.014e-01  3.041e-05]
#  [ 0.000e+00  0.000e+00  0.000e+00]
#  [-3.272e-02  2.302e-12  7.985e-13]
#  [-3.028e-09  5.024e-11  1.520e-05]
#  [ 0.000e+00  0.000e+00  0.000e+00]
#  [-1.520e-05  4.416e-10 -2.143e-13]
#  [ 0.000e+00  3.667e-28 -1.520e-05]
#  [ 0.000e+00 -3.031e-33  0.000e+00]
#  [ 1.520e-05  3.667e-28  0.000e+00]]

# %% [markdown]
# # Add constrains from channel-cut crystals.

# %%
constrain = np.zeros((18, 12))

cc_constrain = np.zeros((6, 3))
cc_constrain[:3,:] = np.eye(3)
cc_constrain[3:,:] = np.eye(3)

constrain[:6, :3] = cc_constrain[:]
constrain[6:12, 3:6] = cc_constrain[:]

constrain[12:, 6:] = np.eye(6)

# %%
gradient_fix_cc = gradient_fix_holder.dot(constrain)

gradient_var_cc = gradient_var_holder.dot(constrain)

# %%
print(np.max(gradient_fix_cc), np.max(gradient_var_cc))
# Out:
# 1.5203192291292867e-05 0.016914407716167024

# %%
print(gradient_fix_cc.T)
# Out:
# [[ 0.000e+00  1.613e-14  1.613e-15]
#  [ 0.000e+00 -2.865e-30 -2.483e-29]
#  [-6.544e-02  2.003e-24  1.127e-24]
#  [ 0.000e+00  4.818e-14 -1.634e-14]
#  [ 0.000e+00 -1.432e-30 -1.241e-29]
#  [-6.544e-02 -1.001e-24  4.882e-24]
#  [ 0.000e+00  8.763e-14 -1.520e-05]
#  [ 0.000e+00  0.000e+00  0.000e+00]
#  [ 1.520e-05  9.779e-28 -1.146e-29]
#  [ 0.000e+00 -3.667e-28  1.520e-05]
#  [ 0.000e+00  3.031e-33  0.000e+00]
#  [-1.520e-05 -3.667e-28  0.000e+00]]

# %%
print(gradient_var_cc.T)
# Out:
# [[ 1.691e-02 -5.593e-07  1.669e-10]
#  [ 4.775e-31  0.000e+00 -2.483e-29]
#  [-6.544e-02  1.901e-06 -5.674e-10]
#  [ 1.691e-02  6.803e-08 -2.031e-11]
#  [ 4.775e-31  0.000e+00 -1.241e-29]
#  [-6.544e-02  4.264e-12  1.420e-12]
#  [-3.028e-09  5.024e-11  1.520e-05]
#  [ 0.000e+00  0.000e+00  0.000e+00]
#  [-1.520e-05  4.416e-10 -2.143e-13]
#  [ 0.000e+00  3.667e-28 -1.520e-05]
#  [ 0.000e+00 -3.031e-33  0.000e+00]
#  [ 1.520e-05  3.667e-28  0.000e+00]]
