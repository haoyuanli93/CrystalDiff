# %%
import numpy as np
import h5py as h5
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
# Variable Delay Branch
k_variable_holders = []

with h5.File("C:/Users/haoyuan/Desktop/Research/Projects/Split Delay Design/instability_inclined.h5", 'r') as source:
    name_list = list(source.keys())
    for k in list(source.keys()):
        print(k)
        k_variable_holders.append(np.array(source[k]))
        #print(source[k].shape)

# ===============================================================================================================
k_fixed_holders = []

with h5.File("C:/Users/haoyuan/Desktop/Research/Projects/Split Delay Design/instability_inclined.h5", 'r') as source:
    for k in list(source.keys()):
        #print(k)
        k_fixed_holders.append(np.array(source[k]))
        #print(source[k].shape)
# Out:
# crystal 0 x axis
# crystal 0 y axis
# crystal 0 z axis
# crystal 1 x axis
# crystal 1 y axis
# crystal 1 z axis
# crystal 2 x axis
# crystal 2 y axis
# crystal 2 z axis
# crystal 3 x axis
# crystal 3 y axis
# crystal 3 z axis
# grating 1 x axis
# grating 1 y axis
# grating 1 z axis
# grating 2 x axis
# grating 2 y axis
# grating 2 z axis

# %% [markdown]
# # Get the unperturbed wave vector

# %%
k0_fix = k_fixed_holders[0][100]
print(k0_fix)

k0_var = k_variable_holders[0][100]
print(k0_var)
# Out:
# [1.21700144e-06 3.64625105e-06 5.06773076e+04]
# [1.21700144e-06 3.64625105e-06 5.06773076e+04]

# %% [markdown]
# # Calculate the momentum difference

# %%
k_fix = np.stack(k_fixed_holders)
k_fix_diff = k_fix - k0_fix[np.newaxis, np.newaxis, :]

k_var = np.stack(k_variable_holders)
k_var_diff = k_var - k0_var[np.newaxis, np.newaxis, :]

# %% [markdown]
# # plot the differences

# %%
plt.figure(figsize=(15, 7))

for x in range(18):
    plt.plot(np.arange(-100, 101) / 10., k_fix_diff[x, :, 0], label=name_list[x])

plt.xlim([-11, 15])

plt.ylabel("Delta k in um^-1")
plt.xlabel("Misalignment in urad")
plt.title("Delta kx")

plt.legend()
plt.show()

# %%
plt.figure(figsize=(15, 7))

for x in range(18):
    plt.plot(np.arange(-100, 101) / 10., k_fix_diff[x, :, 1], label=name_list[x])

plt.xlim([-11, 15])

plt.ylabel("Delta k in um^-1")
plt.xlabel("Misalignment in urad")
plt.title("Delta ky")

plt.legend()
plt.show()

# %%
plt.figure(figsize=(15, 7))

for x in range(18):
    plt.plot(np.arange(-100, 101) / 10., k_fix_diff[x, :, 2], label=name_list[x])

plt.xlim([-11, 15])

plt.ylabel("Delta k in um^-1")
plt.xlabel("Misalignment in urad")
plt.title("Delta kz")

plt.legend()
plt.show()

# %% [markdown]
# # Fit the Deviation Matrix

# %%
gradient_fix_holder = np.zeros((3, 18))

angles = np.arange(-100, 101) / 10.  # urad

for x in range(18):
    for y in range(3):
        
        # Linear fit slope
        slope, intercept, r_value, p_value, std_err = linregress(angles, k_fix_diff[x, :, y])

        # Slope through the origin
        slope_o = np.dot(angles, k_fix_diff[x, :, y]) / np.dot(angles, angles)
        
        #print(slope - slope_o)
        
        gradient_fix_holder[y, x] = slope_o

# %%
gradient_var_holder = np.zeros((3, 18))

angles = np.arange(-100, 101) / 10.  # urad

for x in range(18):
    for y in range(3):
        
        # Linear fit slope
        slope, intercept, r_value, p_value, std_err = linregress(angles, k_var_diff[x, :, y])

        # Slope through the origin
        slope_o = np.dot(angles, k_fix_diff[x, :, y]) / np.dot(angles, angles)
        
        #print(slope - slope_o)
        
        gradient_var_holder[y, x] = slope_o

# %%
print(np.max(gradient_fix_holder), np.max(gradient_var_holder))

print(gradient_fix_holder)
# Out:
# 0.1013546832003189 0.1013546832003189
# [[ 6.76572575e-02  4.77489917e-31 -3.27214780e-02 -5.07430592e-02
#    0.00000000e+00 -3.27214338e-02  1.69144077e-02  4.77489917e-31
#   -3.27217510e-02  0.00000000e+00  0.00000000e+00 -3.27217952e-02
#   -3.02783482e-09  0.00000000e+00 -1.52030449e-05  0.00000000e+00
#    0.00000000e+00  1.52031923e-05]
#  [ 1.01353633e-01  0.00000000e+00  9.50415549e-07 -1.01354192e-01
#    0.00000000e+00  9.50415298e-07  1.01354683e-01  0.00000000e+00
#    1.96196358e-12 -1.01354615e-01  0.00000000e+00  2.30220004e-12
#    5.02418317e-11  0.00000000e+00  4.41610237e-10  3.66712256e-28
#   -3.03094186e-33  3.66712256e-28]
#  [-3.04060904e-05 -1.24147378e-29 -2.83470534e-10  3.04062573e-05
#   -1.24147378e-29 -2.83881480e-10 -3.04064121e-05 -1.24147378e-29
#    6.21472366e-13  3.04063918e-05  0.00000000e+00  7.98452213e-13
#    1.52031921e-05  0.00000000e+00 -2.14289693e-13 -1.52031923e-05
#    0.00000000e+00  0.00000000e+00]]

# %% [markdown]
# # Add constrains from channel-cut crystals.

# %%
constrain = np.zeros((18, 12))

cc_constrain = np.zeros((6, 3))
cc_constrain[:3,:] = np.eye(3)
cc_constrain[3:,:] = np.eye(3)

constrain[:6, :3] = cc_constrain[:]
constrain[6:12, 3:6] = cc_constrain[:]

constrain[12:, 6:] = np.eye(6)

# %%
gradient_fix_cc = gradient_fix_holder.dot(constrain)

gradient_var_cc = gradient_var_holder.dot(constrain)

# %%
print(np.max(gradient_fix_cc), np.max(gradient_var_cc))
# Out:
# 0.016914407716167024 0.016914407716167024

# %%
print(gradient_fix_cc)
# Out:
# [[ 1.69141983e-02  4.77489917e-31 -6.54429118e-02  1.69144077e-02
#    4.77489917e-31 -6.54435462e-02 -3.02783482e-09  0.00000000e+00
#   -1.52030449e-05  0.00000000e+00  0.00000000e+00  1.52031923e-05]
#  [-5.59286808e-07  0.00000000e+00  1.90083085e-06  6.80265480e-08
#    0.00000000e+00  4.26416362e-12  5.02418317e-11  0.00000000e+00
#    4.41610237e-10  3.66712256e-28 -3.03094186e-33  3.66712256e-28]
#  [ 1.66884577e-10 -2.48294757e-29 -5.67352015e-10 -2.03102115e-11
#   -1.24147378e-29  1.41992458e-12  1.52031921e-05  0.00000000e+00
#   -2.14289693e-13 -1.52031923e-05  0.00000000e+00  0.00000000e+00]]
